# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# #### Content

# %% [markdown]
# 1. acc_max: Maximum acceleration magnitude of 4th second of the window.
#
# 2. acc_kurtosis: Acceleration kurtosis of the whole window.
#
# 3. acc_skewness: Acceleration skewness of the whole window.
#
# 4. gyro_max: Maximum gyroscope magnitude of 4th second of the window.
#
# 5. gyro_kurtosis: Gyroscope kurtosis of the whole window.
#
# 6. gyro_skewness: Gyroscope skewness of the whole window.
#
# 7. lin_max: Maximum linear acceleration (acceleration excluding gravity) of 4th second of the window.
#
# 8. post_lin_max: Maximum linear acceleration of the 6th second.
#
# 9. post_gyro_max: Maximum gyroscope magnitude of the 6th second.
#
# 10. fall: 1 if the activity is a fall activity otherwise 0.
#
# 11. label: The activity label.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv("data/patient_footfall.csv", index_col=0)

# %% [markdown]
# EDA + Preprocessing = FEATURE ENGINEERING
#
# Feature Engineering means null value, encode the data, transform the data is required.
#
# Whenever we are going to do EDA
#
# we are divide into the multiple steps
#
#     1. Simple Profile (We will create a simple profile of the data)
#
#     2. Stats Based Analysis
#
#     3. Graphs Based Analysis
#
# Profile of the Data
#
# A. How many rows is there
#
# B. How many columns is there
#
# C. How many missing value is there
#
# D. How many outliers is there
#
# E. Size
#
# F. Duplicates
#
# G. Basic Types
#
# H. Numerical & Categorical Columns
#
# I. How many RAM It is occupied
#
# and so on.
#
# (Basic Information about the data)
#
# If our data is messy, or if not correct in terms of contents, -------------> DATA CLEANING Statistics Based Analysis
#
# A. Mean, Median, Mode
#
# B. Variance
#
# C. Standard Deviation
#
# D. Covariance
#
# E. Correlation
#
# F. Chi Squared Test
#
# G. T-Test
#
# H. Z-Test
#
# I. F-Test
#
# J. Skewness
#
# K. Mean, Median, Mode of the data
#
# L. Range
#
# M. Percentile
#
# Graph Based Analysis
#
# In Graph Based Analysis, You can make statical conclusion
#
# A. Box Plot
#
# B. Scatter Plot
#
# C. KDE
#
# D. Count Plot
#
# E. Histogram
#
# F. Heatmap
#
# After EDA We will going to the Feature Engineering

# %% [markdown]
# #### 1. Profile of the data

# %%
data
# Out:
#         acc_max   gyro_max  acc_kurtosis  gyro_kurtosis label    lin_max  \
# 0     26.039919   7.309797     20.378162       2.782476   SDL  11.131080
# 1     25.864500   6.511954     14.187190       5.324864   FOL   7.945561
# 2     27.524501  12.944099     31.855926      22.891186   FOL  14.454818
# 3     30.647705  11.694868     23.608764       9.287735   FOL  15.228303
# 4     26.373917  11.168424     14.318453      15.983202   FKL  10.007396
# ...         ...        ...           ...            ...   ...        ...
# 1779  20.882939   2.708036      2.619582       1.315623   WAL   6.399551
# 1780  22.100430   3.427954      2.197909       0.420868   WAL   6.886338
# 1781  21.950314   4.113075      1.185087      -0.583776   WAL   5.659883
# 1782  24.504250   6.026591     -0.663832      -0.563054   WAL  11.443950
# 1783  24.053077   3.656559      1.416664      -0.690195   WAL   8.623172
#
#       acc_skewness  gyro_skewness  post_gyro_max  post_lin_max  fall
# ...

# %%
data.shape
# Out:
# (1784, 11)

# %%
data.iloc[1]
# Out:
# acc_max           25.8645
# gyro_max         6.511954
# acc_kurtosis     14.18719
# gyro_kurtosis    5.324864
# label                 FOL
# lin_max          7.945561
# acc_skewness     3.022175
# gyro_skewness    2.376939
# post_gyro_max    6.325522
# post_lin_max     7.719352
# fall                    1
# Name: 1, dtype: object

# %%
data.sample(4)
# Out:
#         acc_max   gyro_max  acc_kurtosis  gyro_kurtosis label    lin_max  \
# 617   10.055318   0.222049      3.167660      13.943183   STD   0.144888
# 1055  18.762078   2.490961     -0.103779      -0.071627   WAL   5.312469
# 324   28.311244  11.369639     32.393753      25.929407   FKL  14.853706
# 847   10.039269   0.129596      2.049466       0.377220   STD   0.250096
#
#       acc_skewness  gyro_skewness  post_gyro_max  post_lin_max  fall
# 617       0.383374       2.939892       0.148176      0.004242     0
# 1055      0.431143       0.378543       0.312536      1.504351     0
# 324       4.662709       4.508626      11.180351     14.567545     1
# 847      -0.300773       0.774013       0.051219      0.082220     0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1784 entries, 0 to 1783
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   acc_max        1784 non-null   float64
#  1   gyro_max       1784 non-null   float64
#  2   acc_kurtosis   1784 non-null   float64
#  3   gyro_kurtosis  1784 non-null   float64
#  4   label          1784 non-null   object
#  5   lin_max        1784 non-null   float64
#  6   acc_skewness   1784 non-null   float64
#  7   gyro_skewness  1784 non-null   float64
#  8   post_gyro_max  1784 non-null   float64
#  9   post_lin_max   1784 non-null   float64
#  10  fall           1784 non-null   int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 167.2+ KB

# %%
data.describe().T
# Out:
#                 count       mean        std        min        25%        50%  \
# acc_max        1784.0  21.768998   5.479980   9.787964  18.751488  22.924268
# gyro_max       1784.0   5.028728   2.943876   0.026257   3.104216   4.568088
# acc_kurtosis   1784.0  10.031186  11.836305  -1.743347   0.469997   8.423476
# gyro_kurtosis  1784.0   3.916387   5.489329  -1.532044   0.186524   2.028413
# lin_max        1784.0   7.976308   4.258842   0.043625   4.832765   8.282902
# acc_skewness   1784.0   1.732918   1.529711 -14.066208   0.458187   1.520431
# gyro_skewness  1784.0   1.629258   0.999016  -0.460160   0.811557   1.542694
# post_gyro_max  1784.0   3.191397   3.429678  -4.984168   0.286294   2.452813
# post_lin_max   1784.0   5.228546   5.004165  -5.382828   0.907965   3.727967
# fall           1784.0   0.429933   0.495205   0.000000   0.000000   0.000000
#
#                      75%         max
# acc_max        25.865634   32.885551
# gyro_max        6.428771   17.288546
# ...

# %%
data.isnull().sum()
# Out:
# acc_max          0
# gyro_max         0
# acc_kurtosis     0
# gyro_kurtosis    0
# label            0
# lin_max          0
# acc_skewness     0
# gyro_skewness    0
# post_gyro_max    0
# post_lin_max     0
# fall             0
# dtype: int64

# %%
data.size
# Out:
# 19624

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["fall"].value_counts()
# Out:
# 0    1017
# 1     767
# Name: fall, dtype: int64

# %%
data.columns
# Out:
# Index(['acc_max', 'gyro_max', 'acc_kurtosis', 'gyro_kurtosis', 'label',
#        'lin_max', 'acc_skewness', 'gyro_skewness', 'post_gyro_max',
#        'post_lin_max', 'fall'],
#       dtype='object')

# %% [markdown]
# #### Seperating Numerical And Categorical Columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1784 entries, 0 to 1783
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   acc_max        1784 non-null   float64
#  1   gyro_max       1784 non-null   float64
#  2   acc_kurtosis   1784 non-null   float64
#  3   gyro_kurtosis  1784 non-null   float64
#  4   label          1784 non-null   object
#  5   lin_max        1784 non-null   float64
#  6   acc_skewness   1784 non-null   float64
#  7   gyro_skewness  1784 non-null   float64
#  8   post_gyro_max  1784 non-null   float64
#  9   post_lin_max   1784 non-null   float64
#  10  fall           1784 non-null   int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 167.2+ KB

# %%
data.columns
# Out:
# Index(['acc_max', 'gyro_max', 'acc_kurtosis', 'gyro_kurtosis', 'label',
#        'lin_max', 'acc_skewness', 'gyro_skewness', 'post_gyro_max',
#        'post_lin_max', 'fall'],
#       dtype='object')

# %%
categorical_columns = data.columns[data.dtypes=="O"]
numerical_columns = data.columns[data.dtypes!="O"]

# %%
print("Categorical columns are: ", categorical_columns)
print("-"*130)
print("Numerical columns are: ", numerical_columns)
# Out:
# Categorical columns are:  Index(['label'], dtype='object')
# ----------------------------------------------------------------------------------------------------------------------------------
# Numerical columns are:  Index(['acc_max', 'gyro_max', 'acc_kurtosis', 'gyro_kurtosis', 'lin_max',
#        'acc_skewness', 'gyro_skewness', 'post_gyro_max', 'post_lin_max',
#        'fall'],
#       dtype='object')

# %% [markdown]
# #### Getting unique values of categorical data

# %%
for i in categorical_columns:
    print(i, "---->", data[i].unique())
# Out:
# label ----> ['SDL' 'FOL' 'FKL' 'BSC' 'STU' 'JUM' 'STD' 'WAL' 'CSI' 'CSO' 'STN' 'JOG'
#  'SCH']

# %% [markdown]
# #### 2. Statistics Based Analysis

# %%
data[numerical_columns].describe().T
# Out:
#                 count       mean        std        min        25%        50%  \
# acc_max        1784.0  21.768998   5.479980   9.787964  18.751488  22.924268
# gyro_max       1784.0   5.028728   2.943876   0.026257   3.104216   4.568088
# acc_kurtosis   1784.0  10.031186  11.836305  -1.743347   0.469997   8.423476
# gyro_kurtosis  1784.0   3.916387   5.489329  -1.532044   0.186524   2.028413
# lin_max        1784.0   7.976308   4.258842   0.043625   4.832765   8.282902
# acc_skewness   1784.0   1.732918   1.529711 -14.066208   0.458187   1.520431
# gyro_skewness  1784.0   1.629258   0.999016  -0.460160   0.811557   1.542694
# post_gyro_max  1784.0   3.191397   3.429678  -4.984168   0.286294   2.452813
# post_lin_max   1784.0   5.228546   5.004165  -5.382828   0.907965   3.727967
# fall           1784.0   0.429933   0.495205   0.000000   0.000000   0.000000
#
#                      75%         max
# acc_max        25.865634   32.885551
# gyro_max        6.428771   17.288546
# ...

# %%
data[categorical_columns].describe().T
# Out:
#       count unique  top freq
# label  1784     13  SDL  192

# %%
data[categorical_columns].value_counts()
# Out:
# label
# FKL      192
# FOL      192
# SDL      192
# BSC      191
# CSI      113
# CSO      113
# JOG      113
# JUM      113
# SCH      113
# STD      113
# STN      113
# STU      113
# WAL      113
# dtype: int64

# %% [markdown]
# #### 3. Graph Based Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

plt.figure(figsize=(8,8))
for i in numerical_columns:
    sns.histplot(data=data, x = i, kde=True)
    print("\n")
    plt.show()

# %%
plt.figure(figsize=(7,7))
x = 1
for i in categorical_columns:
    sns.countplot(data=data, x=i)
    print("\n")
    plt.show()

# %%
categorical_columns
# Out:
# Index(['label'], dtype='object')

# %%
sns.heatmap(data.drop(["label"], axis=1).corr(), annot=True, cmap="Greens")
# Out:
# <Axes: >

# %%
data.hist(figsize=(25,13))
# Out:
# array([[<Axes: title={'center': 'acc_max'}>,
#         <Axes: title={'center': 'gyro_max'}>,
#         <Axes: title={'center': 'acc_kurtosis'}>],
#        [<Axes: title={'center': 'gyro_kurtosis'}>,
#         <Axes: title={'center': 'lin_max'}>,
#         <Axes: title={'center': 'acc_skewness'}>],
#        [<Axes: title={'center': 'gyro_skewness'}>,
#         <Axes: title={'center': 'post_gyro_max'}>,
#         <Axes: title={'center': 'post_lin_max'}>],
#        [<Axes: title={'center': 'fall'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data
# Out:
#         acc_max   gyro_max  acc_kurtosis  gyro_kurtosis label    lin_max  \
# 0     26.039919   7.309797     20.378162       2.782476   SDL  11.131080
# 1     25.864500   6.511954     14.187190       5.324864   FOL   7.945561
# 2     27.524501  12.944099     31.855926      22.891186   FOL  14.454818
# 3     30.647705  11.694868     23.608764       9.287735   FOL  15.228303
# 4     26.373917  11.168424     14.318453      15.983202   FKL  10.007396
# ...         ...        ...           ...            ...   ...        ...
# 1779  20.882939   2.708036      2.619582       1.315623   WAL   6.399551
# 1780  22.100430   3.427954      2.197909       0.420868   WAL   6.886338
# 1781  21.950314   4.113075      1.185087      -0.583776   WAL   5.659883
# 1782  24.504250   6.026591     -0.663832      -0.563054   WAL  11.443950
# 1783  24.053077   3.656559      1.416664      -0.690195   WAL   8.623172
#
#       acc_skewness  gyro_skewness  post_gyro_max  post_lin_max  fall
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool_))
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(150, 1, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap="bwr", vmax=None, center=0,square=True, annot=True, linewidths=.5, cbar_kws={"shrink": .9})
# Out:
# C:\Users\msant\AppData\Local\Temp\ipykernel_916\1672975966.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <Axes: >

# %% [markdown]
# # Findings

# %% [markdown]
# 1. In dataset dont have missing values
#
# 2. No duplicates
#
# 3. We can see from the plot that post_line_max and post_gyro_max has the highest positive correlation with the fall target column. Which is 86% and 76%
#
# 4. gyro_max column has a very least similarity with the fall target column which is 47% only.
#
# 5. gyro_max column is a negative correlation.
#
# 6. Except gyro_max column, rest all other columns has a positive correlation, because the correaltion value is more than 50% with the target column.

# %% [markdown]
#                                                     Completed
